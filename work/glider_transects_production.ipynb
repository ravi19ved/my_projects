# %% [markdown]
# ##  This is the working copy of the code used for plotting glider transects on a map using pygmt.
#
# 1. Here the glider transect files (csv files) are given as a list of csv files.

# %%
# Library Imports
import pygmt
import pandas as pd
import numpy as np

# %%
# Loading Glider Transects Data from CSV files
'''
mission_files = [f'mission_{i}' for i in range(1,11)]
for i, mission_name in enumerate(mission_files, start=1):
    transect_data = pd.DataFrame({
        "longitude":np.random.uniform(48, 105, 50),
        "latitude": np.random.uniform(-20, 28, 50)
    })
    transect_data.to_csv(f"glider_transect_{mission_name}.csv", index = False)
'''

glider_transect_files = [
    "track_1126_Antarctica.csv",
    "track_1129_Mauritius.csv",
    "track_1127.csv",
    "track_1128.csv",
    "track_1130.csv"
    ]

# Define a list of colors for glider transects
glider_colors = [
    "red", "purple", "orange", "cyan", "yellow", 
]

# Map Initialization

fig = pygmt.Figure()
fig.basemap(region=[46, 110, -20, 28], projection="M6i", frame="af")
#  bkp: fig.basemap(region=[5, 45, -75, -60], projection="M6i", frame="af")
fig.coast(land='lightgray', water='skyblue', borders=[1,2],shorelines="1/thinner")

# Add map title
#fig.text(text="Glider Transects over Indian Ocean Region (2024-25)", position="TC", font="14p,Helvetica-Bold,black")

# Add region labels
#fig.text(text="Bay of Bengal", x=88, y=15, font="12p,Helvetica-Bold,blue")
#fig.text(text="Arabian Sea", x=65, y=15, font="12p,Helvetica-Bold,blue")

# Plot Glider Transects
for track_file, color in zip(glider_transect_files, glider_colors):
    mission_name = track_file.split("_")[-1].replace(".csv", "") 
    transect_data=pd.read_csv(track_file)
   
    fig.plot(
        x=transect_data["Longitude"],
        y=transect_data["Latitude"],
        pen=f"1p,{color}", label=mission_name
    )

# Add Legend
fig.legend(position = "JBR+jBR+o0.5c", box='1p, black, gray')
#fig.legend(position="JBR+jBR+o0.5c", box=True)

fig.savefig("glider_transects_io_1.jpeg")

# Show Map
fig.show()

# %%
# Loading Glider Transects Data from CSV files
'''
mission_files = [f'mission_{i}' for i in range(1,11)]
for i, mission_name in enumerate(mission_files, start=1):
    transect_data = pd.DataFrame({
        "longitude":np.random.uniform(48, 105, 50),
        "latitude": np.random.uniform(-20, 28, 50)
    })
    transect_data.to_csv(f"glider_transect_{mission_name}.csv", index = False)
'''

# BHARATI = [-69.40805555555556, 76.18722222222223] # 69°24′29″S 76°11′14″E
# MAITRI = [-70.82138888888889, 11.643333333333333] # 70°49′17″S 11°38′36″E

glider_transect_files = [
    "track_1126_Antarctica.csv",
    "track_1129_Mauritius.csv",
    "track_1127.csv",
    "track_1128.csv",
    "track_1130.csv"
    ]

# Define a list of colors for glider transects
glider_colors = [
    "red", "purple", "orange", "cyan", "yellow", 
]

# Map Initialization

fig = pygmt.Figure()
#  bkp: fig.basemap(region=[46, 110, -20, 28], projection="M6i", frame="af")
fig.basemap(region=[-20, 50, -75, -55], projection="Poly/12c", frame="afg")
fig.coast(land='lightgray', water='skyblue', borders=[1,2],shorelines="1/thinner", frame="afg")

# Add map title
#fig.text(text="Glider Transects over Antarctic Region (2024-25)", position="TC", font="14p,Helvetica-Bold,black")

# Add region labels
# fig.text(text="Bay of Bengal", x=88, y=15, font="12p,Helvetica-Bold,blue")
# fig.text(text="Arabian Sea", x=65, y=15, font="12p,Helvetica-Bold,blue")

# Plot Glider Transects
for track_file, color in zip(glider_transect_files, glider_colors):
    mission_name = track_file.split("_")[-1].replace(".csv", "") 
    transect_data=pd.read_csv(track_file)
   
    fig.plot(
        x=transect_data["Longitude"],
        y=transect_data["Latitude"],
        pen=f"1p,{color}", label=mission_name
    )


fig.plot(
    x= 24.78248333,
    y=-66.53318333,
    style = "c0.3c", pen=f"1p,{color}", label= "deployment location"
)

# Add Legend
#fig.legend(position = "JBR+jBR+o0.5c", box='1p, black, gray')
#fig.legend(position="JBR+jBR+o0.5c", box=True)

fig.savefig("glider_transects_io_2.jpeg")

# Show Map
fig.show()

# %%
import pygmt

fig = pygmt.Figure()
fig.coast(
    region=[5, 45, -75, -60],
    projection="Poly/12c",
    frame="afg",
    land="seagreen",
    water="gray90",
)
fig.show()
