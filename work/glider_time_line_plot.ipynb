# %%
## This is with dummy data.  Now you can use original data to have the plot.

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# Sample data (glider number, deployment date, retrieval date)
data = {
    'Glider': [350, 351, 890, 891, 1126, 1127, 1128, 1129, 1130, 1131],
    'Deployment Date': [
        '2023-01-15', '2023-02-20', '2023-03-10', '2023-04-01', '2023-05-05',
        '2023-06-15', '2023-07-20', '2023-08-25', '2023-09-15', '2023-10-05'
    ],
    'Retrieval Date': [
        '2023-02-01', '2023-03-01', '2023-04-15', '2023-05-10', '2023-06-20',
        '2023-07-30', '2023-08-15', '2023-09-30', '2023-10-20', '2023-11-01'
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Convert date strings to datetime objects
df['Deployment Date'] = pd.to_datetime(df['Deployment Date'])
df['Retrieval Date'] = pd.to_datetime(df['Retrieval Date'])
df['Operational Days'] = (df['Retrieval Date'] - df['Deployment Date']).dt.days

# Set up the plot
plt.figure(figsize=(12, 8))

# Plot horizontal bars with date ranges
for idx, row in df.iterrows():
    plt.plot(
        [row['Deployment Date'], row['Retrieval Date']], 
        [idx, idx],
        marker='o',
        color='skyblue',
        linewidth=8,  # Increased bar width
        label=f'Glider {row["Glider"]}' if idx == 0 else ""
    )
    # Add green dot for deployment date
    plt.plot(
        row['Deployment Date'], 
        idx, 
        marker='o', 
        color='green', 
        markersize=10,  # Size of the dot
        label='Deployment Date' if idx == 0 else ""
    )
    # Add red dot for retrieval date
    plt.plot(
        row['Retrieval Date'], 
        idx, 
        marker='o', 
        color='red', 
        markersize=10,  # Size of the dot
        label='Retrieval Date' if idx == 0 else ""
    )
    # Add operational days text on the bar
    plt.text(
        (row['Deployment Date'] + (row['Retrieval Date'] - row['Deployment Date']) / 2), 
        idx, 
        f'{row["Operational Days"]} days',
        ha='center',
        va='center',
        color='black',
        fontsize=10,
        fontweight='bold'
    )

# Customize x-axis to show date ranges
plt.xlabel('Date')
plt.ylabel('Glider Number')
plt.title('Operational Period for Each Glider')
plt.grid(True, linestyle='--', alpha=0.7)

# Set date format on x-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gcf().autofmt_xdate()  # Rotate date labels for better readability

# Add annotations for deployment and retrieval dates
for idx, row in df.iterrows():
    plt.text(
        row['Deployment Date'], 
        idx + 0.1, 
        row['Deployment Date'].strftime('%Y-%m-%d'),
        ha='center',
        va='bottom'
    )
    plt.text(
        row['Retrieval Date'], 
        idx + 0.1, 
        row['Retrieval Date'].strftime('%Y-%m-%d'),
        ha='center',
        va='bottom'
    )

# Set y-ticks to glider numbers and remove extra y-axis labels
plt.yticks(range(len(df)), df['Glider'])

# Add a legend to identify the dots
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ravic\AppData\Local\Temp\ipykernel_36824\472746464.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
## Working Code.

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# Sample data (glider number, deployment date, retrieval date)
data = {
    'Glider': [350, 351, 890, 891, 1126, 1127, 1128, 1129, 1130, 1131],
    'Deployment Date': [
        '2023-01-15', '2023-02-20', '2023-03-10', '2023-04-01', '2023-05-05',
        '2023-06-15', '2023-07-20', '2023-08-25', '2023-09-15', '2023-10-05'
    ],
    'Retrieval Date': [
        '2023-02-01', '2023-03-01', '2023-04-15', '2023-05-10', '2023-06-20',
        '2023-07-30', '2023-08-15', '2023-09-30', '2023-10-20', '2023-11-01'
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Convert date strings to datetime objects
df['Deployment Date'] = pd.to_datetime(df['Deployment Date'])
df['Retrieval Date'] = pd.to_datetime(df['Retrieval Date'])
df['Operational Days'] = (df['Retrieval Date'] - df['Deployment Date']).dt.days

# Set up the plot
plt.figure(figsize=(12, 8))

# Plot horizontal bars with date ranges
for idx, row in df.iterrows():
    plt.plot(
        [row['Deployment Date'], row['Retrieval Date']], 
        [idx, idx],
        marker='o',
        color='skyblue',
        linewidth=8,  # Increased bar width
        label=f'Glider {row["Glider"]}' if idx == 0 else ""
    )
    # Add green dot for deployment date
    plt.plot(
        row['Deployment Date'], 
        idx, 
        marker='o', 
        color='green', 
        markersize=10,  # Size of the dot
        label='Deployment Date' if idx == 0 else ""
    )
    # Add red dot for retrieval date
    plt.plot(
        row['Retrieval Date'], 
        idx, 
        marker='o', 
        color='red', 
        markersize=10,  # Size of the dot
        label='Retrieval Date' if idx == 0 else ""
    )
    # Add operational days text on the bar
    plt.text(
        (row['Deployment Date'] + (row['Retrieval Date'] - row['Deployment Date']) / 2), 
        idx, 
        f'{row["Operational Days"]} days',
        ha='center',
        va='center',
        color='black',
        fontsize=10,
        fontweight='bold'
    )

# Customize x-axis to show date ranges
plt.xlabel('Date')
plt.ylabel('Glider Number')
plt.title('Operational Period for Each Glider')
plt.grid(True, linestyle='--', alpha=0.7)

# Set date format on x-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gcf().autofmt_xdate()  # Rotate date labels for better readability

# Add annotations for deployment and retrieval dates
for idx, row in df.iterrows():
    plt.text(
        row['Deployment Date'], 
        idx + 0.1, 
        row['Deployment Date'].strftime('%Y-%m-%d'),
        ha='center',
        va='bottom'
    )
    plt.text(
        row['Retrieval Date'], 
        idx + 0.1, 
        row['Retrieval Date'].strftime('%Y-%m-%d'),
        ha='center',
        va='bottom'
    )

# Set y-ticks to glider numbers and remove extra y-axis labels
plt.yticks(range(len(df)), df['Glider'])

# Add a legend to identify the dots
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
from datetime import datetime

# Data: Replace these with your actual deployment and retrieval dates
glider_data = {
    'Glider': ['890', '891', '1126', '1127', '1128', '1129', '1130', '1131'],
    'Deployment Date': ['2024-01-10', '2024-02-05', '2024-03-12', '2024-04-01', '2024-05-15', '2024-06-10', '2024-07-01', '2024-08-01'],
    'Retrieval Date': ['2024-02-10', '2024-03-15', '2024-04-12', '2024-05-01', '2024-06-15', '2024-07-10', '2024-08-01', '2024-08-20']
}

# Convert dates to datetime
glider_data['Deployment Date'] = pd.to_datetime(glider_data['Deployment Date'])
glider_data['Retrieval Date'] = pd.to_datetime(glider_data['Retrieval Date'])

# Calculate the number of operational days
glider_data['Operational Days'] = (glider_data['Retrieval Date'] - glider_data['Deployment Date']).dt.days

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Create horizontal bars
bars = ax.barh(glider_data['Glider'], glider_data['Operational Days'], color='skyblue')

# Add the number of operational days on top of each bar
for bar, days in zip(bars, glider_data['Operational Days']):
    ax.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2, f'{days} days', va='center', ha='left')

# Add green dot for deployment date and red dot for retrieval date
for idx, row in glider_data.iterrows():
    ax.plot(row['Deployment Date'], idx, 'go')  # Green dot for deployment date
    ax.plot(row['Retrieval Date'], idx, 'ro')   # Red dot for retrieval date

# Format the x-axis to show dates
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# Set labels and title
ax.set_xlabel('Operational Days')
ax.set_ylabel('Glider Number')
ax.set_title('Operational Days of Slocum Gliders')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 18
#      15 glider_data['Retrieval Date'] = pd.to_datetime(glider_data['Retrieval Date'])
#      17 # Calculate the number of operational days
# ---> 18 glider_data['Operational Days'] = (glider_data['Retrieval Date'] - glider_data['Deployment Date']).dt.days
#      20 # Plotting
#      21 fig, ax = plt.subplots(figsize=(10, 6))
#
# AttributeError: 'TimedeltaIndex' object has no attribute 'dt'

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Sample data: Glider names and their corresponding start and end operational dates
data = {
    'Glider': ['Glider1', 'Glider2', 'Glider3', 'Glider4', 'Glider5', 'Glider6', 'Glider7', 'Glider8', 'Glider9', 'Glider10'],
    'Start_Date': ['2024-01-01', '2024-01-15', '2024-02-01', '2024-02-15', '2024-03-01', '2024-03-15', '2024-04-01', '2024-04-15', '2024-05-01', '2024-05-15'],
    'End_Date': ['2024-01-31', '2024-02-14', '2024-02-28', '2024-03-14', '2024-03-31', '2024-04-14', '2024-04-30', '2024-05-14', '2024-05-31', '2024-06-14']
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Convert Start_Date and End_Date to datetime objects
df['Start_Date'] = pd.to_datetime(df['Start_Date'])
df['End_Date'] = pd.to_datetime(df['End_Date'])

# Calculate the duration of operations
df['Duration'] = df['End_Date'] - df['Start_Date']

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Create horizontal bars
for idx, row in df.iterrows():
    ax.barh(row['Glider'], row['Duration'].days, left=row['Start_Date'], height=0.4)

# Formatting date on x-axis
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Operational Days')
ax.set_ylabel('Gliders')
ax.set_title('Glider Operational Days')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Sample data: Glider names, their corresponding start and end operational dates
data = {
    'Glider': ['Glider1', 'Glider2', 'Glider2', 'Glider3', 'Glider4', 'Glider5', 'Glider6', 'Glider7', 'Glider8', 'Glider9', 'Glider9', 'Glider10'],
    'Start_Date': ['2024-01-01', '2024-01-15', '2024-06-01', '2024-02-01', '2024-02-15', '2024-03-01', '2024-03-15', '2024-04-01', '2024-04-15', '2024-05-01', '2024-07-01', '2024-05-15'],
    'End_Date':   ['2024-01-31', '2024-02-14', '2024-06-30', '2024-02-28', '2024-03-14', '2024-03-31', '2024-04-14', '2024-04-30', '2024-05-14', '2024-05-31', '2024-07-31', '2024-06-14']
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Convert Start_Date and End_Date to datetime objects
df['Start_Date'] = pd.to_datetime(df['Start_Date'])
df['End_Date'] = pd.to_datetime(df['End_Date'])

# Calculate the duration of operations
df['Duration'] = df['End_Date'] - df['Start_Date']

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

# Create horizontal bars
for idx, row in df.iterrows():
    ax.barh(row['Glider'], row['Duration'].days, left=row['Start_Date'], height=0.4)

# Formatting date on x-axis
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Operational Days')
ax.set_ylabel('Gliders')
ax.set_title('Glider Operational Days with Multiple Deployments')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Glider deployment data with repeat deployments for gliders 890, 891, and 1127
data = {
    'Glider': ['890', '890', '891', '891', '1096', '1097', '1126', '1127', '1127', '1128', '1129', '1130', '1131'],
    'Start_Date': ['2024-01-01', '2024-06-01', '2024-01-15', '2024-07-01', '2024-02-01', '2024-02-15', '2024-03-01', '2024-03-15', '2024-08-01', '2024-04-01', '2024-04-15', '2024-05-01', '2024-05-15'],
    'End_Date':   ['2024-01-31', '2024-06-30', '2024-02-14', '2024-07-31', '2024-02-28', '2024-03-14', '2024-03-31', '2024-04-14', '2024-08-30', '2024-04-30', '2024-05-14', '2024-05-31', '2024-06-14']
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Convert Start_Date and End_Date to datetime objects
df['Start_Date'] = pd.to_datetime(df['Start_Date'])
df['End_Date'] = pd.to_datetime(df['End_Date'])

# Calculate the duration of operations
df['Duration'] = df['End_Date'] - df['Start_Date']

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

# Create horizontal bars for each deployment
for idx, row in df.iterrows():
    ax.barh(row['Glider'], row['Duration'].days, left=row['Start_Date'], height=0.4)

# Adding grid lines
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Formatting date on x-axis
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Operational Days')
ax.set_ylabel('Gliders')
ax.set_title('Glider Operational Days with Multiple Deployments')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Glider deployment data with repeat deployments for gliders 890, 891, and 1127
data = {
    'Glider': ['890', '890', '891', '891', '1096', '1097', '1126', '1127', '1127', '1128', '1129', '1130', '1131'],
    'Deployment_Date': ['2024-01-01', '2024-06-01', '2024-01-15', '2024-07-01', '2024-02-01', '2024-02-15', '2024-03-01', '2024-03-15', '2024-08-01', '2024-04-01', '2024-04-15', '2024-05-01', '2024-05-15'],
    'Retrieval_Date':   ['2024-01-31', '2024-06-30', '2024-02-14', '2024-07-31', '2024-02-28', '2024-03-14', '2024-03-31', '2024-04-14', '2024-08-30', '2024-04-30', '2024-05-14', '2024-05-31', '2024-06-14']
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Convert Deployment_Date and Retrieval_Date to datetime objects
df['Deployment_Date'] = pd.to_datetime(df['Deployment_Date'])
df['Retrieval_Date'] = pd.to_datetime(df['Retrieval_Date'])

# Calculate the operational days
df['Operational_Days'] = (df['Retrieval_Date'] - df['Deployment_Date']).dt.days

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

# Define a color for all bars
bar_color = '#1f77b4'  # A blue shade

# Create horizontal bars for each deployment
for idx, row in df.iterrows():
    ax.barh(row['Glider'], row['Operational_Days'], left=row['Deployment_Date'], height=0.4, color=bar_color)
    # Add the operational days as text on the bars
    ax.text(row['Retrieval_Date'], row['Glider'], f'{row["Operational_Days"]} days', va='center', ha='left', color='black')

# Adding grid lines
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Formatting date on x-axis
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Deployment Date')
ax.set_ylabel('Gliders')
ax.set_title('Glider Operational Days with Multiple Deployments')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import random

# Seed for reproducibility
np.random.seed(42)

# Glider deployment data
gliders = ['890', '890', '891', '891', '1096', '1097', '1126', '1127', '1127', '1128', '1129', '1130', '1131']

# Generate random deployment dates between February 2021 and March 2024
deployment_dates = pd.to_datetime(np.random.choice(pd.date_range('2021-02-01', '2024-03-31'), size=len(gliders)))

# Generate random operational days between 10 and 225 days
operational_days = np.random.randint(10, 226, size=len(gliders))

# Calculate retrieval dates
retrieval_dates = deployment_dates + pd.to_timedelta(operational_days, unit='D')

# Create a DataFrame
df = pd.DataFrame({
    'Glider': gliders,
    'Deployment_Date': deployment_dates,
    'Retrieval_Date': retrieval_dates,
    'Operational_Days': operational_days
})

# Plotting
fig, ax = plt.subplots(figsize=(14, 8))

# Define a color for all bars
bar_color = '#1f77b4'  # A blue shade

# Create horizontal bars for each deployment
for idx, row in df.iterrows():
    ax.barh(row['Glider'], row['Operational_Days'], left=row['Deployment_Date'], height=0.4, color=bar_color)
    # Add the operational days as text on the bars (on top)
    ax.text(row['Retrieval_Date'] - pd.Timedelta(days=row['Operational_Days']/2), row['Glider'], f'{row["Operational_Days"]} days',
            va='center', ha='center', color='white', fontsize=9, fontweight='bold')
    # Add deployment and retrieval dots
    ax.plot(row['Deployment_Date'], row['Glider'], 'o', color='green')
    ax.plot(row['Retrieval_Date'], row['Glider'], 'o', color='red')

# Adding grid lines
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Formatting date on x-axis
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Gliders')
ax.set_title('Glider Operational Days with Multiple Deployments (Random Dates)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np

# Previous glider deployment data
data = {
    'Glider': ['890', '890', '891', '891', '1096', '1097', '1126', '1127', '1127', '1128', '1129', '1130', '1131'],
    'Deployment_Date': ['2024-01-01', '2024-06-01', '2024-01-15', '2024-07-01', '2024-02-01', '2024-02-15', '2024-03-01', '2024-03-15', '2024-08-01', '2024-04-01', '2024-04-15', '2024-05-01', '2024-05-15'],
    'Retrieval_Date':   ['2024-01-31', '2024-06-30', '2024-02-14', '2024-07-31', '2024-02-28', '2024-03-14', '2024-03-31', '2024-04-14', '2024-08-30', '2024-04-30', '2024-05-14', '2024-05-31', '2024-06-14']
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Convert Deployment_Date and Retrieval_Date to datetime objects
df['Deployment_Date'] = pd.to_datetime(df['Deployment_Date'])
df['Retrieval_Date'] = pd.to_datetime(df['Retrieval_Date'])

# Calculate the operational days
df['Operational_Days'] = (df['Retrieval_Date'] - df['Deployment_Date']).dt.days

# Plotting
fig, ax = plt.subplots(figsize=(14, 8))

# Define a color for all bars
bar_color = '#1f77b4'  # A blue shade

# Create horizontal bars for each deployment
for idx, row in df.iterrows():
    ax.barh(row['Glider'], row['Operational_Days'], left=row['Deployment_Date'], height=0.4, color=bar_color)
    # Add the operational days as text on top of the bars
    ax.text(row['Deployment_Date'] + pd.Timedelta(days=row['Operational_Days']/2), row['Glider'], f'{row["Operational_Days"]} days',
            va='center', ha='center', color='white', fontsize=9, fontweight='bold')
    # Add large green dot for deployment date
    ax.plot(row['Deployment_Date'], row['Glider'], 'o', color='green', markersize=8)
    # Add large red dot for retrieval date
    ax.plot(row['Retrieval_Date'], row['Glider'], 'o', color='red', markersize=8)

# Adding grid lines
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Formatting date on x-axis
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Gliders')
ax.set_title('Glider Operational Days with Multiple Deployments (Specific Dates)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Previous glider deployment data
data = {
    'Glider': ['890', '890', '891', '891', '1096', '1097', '1126', '1127', '1127', '1128', '1129', '1130', '1131'],
    'Deployment_Date': ['2024-01-01', '2024-06-01', '2024-01-15', '2024-07-01', '2024-02-01', '2024-02-15', '2024-03-01', '2024-03-15', '2024-08-01', '2024-04-01', '2024-04-15', '2024-05-01', '2024-05-15'],
    'Retrieval_Date':   ['2024-01-31', '2024-06-30', '2024-02-14', '2024-07-31', '2024-02-28', '2024-03-14', '2024-03-31', '2024-04-14', '2024-08-30', '2024-04-30', '2024-05-14', '2024-05-31', '2024-06-14']
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Convert Deployment_Date and Retrieval_Date to datetime objects
df['Deployment_Date'] = pd.to_datetime(df['Deployment_Date'])
df['Retrieval_Date'] = pd.to_datetime(df['Retrieval_Date'])

# Calculate the operational days
df['Operational_Days'] = (df['Retrieval_Date'] - df['Deployment_Date']).dt.days

# Plotting
fig, ax = plt.subplots(figsize=(14, 8))

# Define a color for all bars
bar_color = '#1f77b4'  # A blue shade

# Create horizontal bars for each deployment
for idx, row in df.iterrows():
    ax.barh(row['Glider'], row['Operational_Days'], left=row['Deployment_Date'], height=0.4, color=bar_color)
    # Add the operational days as text on top of the bars
    ax.text(row['Deployment_Date'] + pd.Timedelta(days=row['Operational_Days']/2), row['Glider'], f'{row["Operational_Days"]} days',
            va='center', ha='center', color='white', fontsize=9, fontweight='bold')
    # Add large green dot for deployment date and label it
    ax.plot(row['Deployment_Date'], row['Glider'], 'o', color='green', markersize=8)
    ax.text(row['Deployment_Date'], row['Glider'], f' {row["Deployment_Date"].strftime("%Y-%m-%d")}', 
            va='center', ha='left', color='green', fontsize=8)
    # Add large red dot for retrieval date and label it
    ax.plot(row['Retrieval_Date'], row['Glider'], 'o', color='red', markersize=8)
    ax.text(row['Retrieval_Date'], row['Glider'], f' {row["Retrieval_Date"].strftime("%Y-%m-%d")}', 
            va='center', ha='left', color='red', fontsize=8)

# Adding grid lines
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Formatting date on x-axis
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Glider Identifier')
ax.set_title('Glider Operational Days in Indian Ocean')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Previous glider deployment data
data = {
    'Glider': ['890', '890', '891', '891', '1095', '1096', '1127', '1127', '1128', '1130', '1131'],
    'Deployment_Date': ['2021-01-26', '2023-03-08', '2021-01-30', '2023-03-08', '2023-09-23', '2023-09-23', '2023-10-27', '2024-07-02', '2024-04-27', '2024-04-27', '2024-01-30'],
    'Retrieval_Date':   ['2021-05-18', '2023-07-07', '2021-05-20', '2023-04-20', '2024-04-23', '2024-03-23', '2024-06-28', '2024-07-10', '2024-12-31', '2024-12-31', '2024-12-31']
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Convert Deployment_Date and Retrieval_Date to datetime objects
df['Deployment_Date'] = pd.to_datetime(df['Deployment_Date'])
df['Retrieval_Date'] = pd.to_datetime(df['Retrieval_Date'])

# Calculate the operational days
df['Operational_Days'] = (df['Retrieval_Date'] - df['Deployment_Date']).dt.days

# Plotting
fig, ax = plt.subplots(figsize=(14, 8))

# Define a color for all bars
bar_color = '#1f77b4' # '#87CEFA'   # A blue shade

# Create horizontal bars for each deployment
for idx, row in df.iterrows():
    ax.barh(row['Glider'], row['Operational_Days'], left=row['Deployment_Date'], height=0.4, color=bar_color)
    # Add the operational days as text on top of the bars
    ax.text(row['Deployment_Date'] + pd.Timedelta(days=row['Operational_Days']/2), row['Glider'], f'{row["Operational_Days"]} days',
            va='center', ha='center', color='white', fontsize=9, fontweight='bold')
    # Add large green dot for deployment date and label it
    ax.plot(row['Deployment_Date'], row['Glider'], 'o', color='green', markersize=8)
    ax.text(row['Deployment_Date'], row['Glider'], f' {row["Deployment_Date"].strftime("%Y-%m-%d")}', 
            va='center', ha='left', color='green', fontsize=8)
    # Add large red dot for retrieval date and label it
    ax.plot(row['Retrieval_Date'], row['Glider'], 'o', color='red', markersize=8)
    ax.text(row['Retrieval_Date'], row['Glider'], f' {row["Retrieval_Date"].strftime("%Y-%m-%d")}', 
            va='center', ha='left', color='red', fontsize=8)

# Adding grid lines
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Formatting date on x-axis
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Glider Identifier')
ax.set_title('Glider Operational Days in Indian Ocean')

plt.tight_layout()
plt.savefig('glider_operational_days.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Glider deployment data
data = {
    'Glider': ['890', '890', '891', '891', '1095', '1096', '1127', '1127', '1128', '1130', '1131'],
    'Deployment_Date': ['2021-01-26', '2023-03-08', '2021-01-30', '2023-03-08', '2023-09-23', '2023-09-23', '2023-10-27', '2024-07-02', '2024-04-27', '2024-04-27', '2024-01-30'],
    'Retrieval_Date':   ['2021-05-18', '2023-07-07', '2021-05-20', '2023-04-20', '2024-04-23', '2024-03-23', '2024-06-28', '2024-07-10', '2024-12-31', '2024-12-31', '2024-12-31']
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Convert Deployment_Date and Retrieval_Date to datetime objects
df['Deployment_Date'] = pd.to_datetime(df['Deployment_Date'])
df['Retrieval_Date'] = pd.to_datetime(df['Retrieval_Date'])

# Calculate the operational days
df['Operational_Days'] = (df['Retrieval_Date'] - df['Deployment_Date']).dt.days

# Plotting
fig, ax = plt.subplots(figsize=(14, 8))

# Define colors
default_bar_color = '#1f77b4'  # A blue shade for completed deployments
in_water_bar_color = '#FFD700'  # Yellow for gliders still in water

# Create horizontal bars for each deployment
for idx, row in df.iterrows():
    # Determine the color based on the glider being in water or not
    bar_color = in_water_bar_color if row['Glider'] in ['1128', '1130', '1131'] else default_bar_color
    
    ax.barh(row['Glider'], row['Operational_Days'], left=row['Deployment_Date'], height=0.4, color=bar_color)
    
    # Add the operational days as text slightly above the bars
    ax.text(row['Deployment_Date'] + pd.Timedelta(days=row['Operational_Days']/2), row['Glider'], f'{row["Operational_Days"]} days',
            va='center', ha='center', color='white', fontsize=9, fontweight='bold')
    
    # Add small vertical line for deployment date
    ax.vlines(row['Deployment_Date'], row['Glider'], row['Glider'], color='green', linewidth=2)
    
    # Add label for deployment date slightly above the bar
    ax.text(row['Deployment_Date'], row['Glider'], f'{row["Deployment_Date"].strftime("%Y-%m-%d")}', 
            va='center', ha='left', color='green', fontsize=8)
    
    # Add small vertical line for retrieval date
    ax.vlines(row['Retrieval_Date'], row['Glider'], row['Glider'], color='red', linewidth=2)
    
    # Add label for retrieval date slightly above the bar
    ax.text(row['Retrieval_Date'], row['Glider'], f'{row["Retrieval_Date"].strftime("%Y-%m-%d")}', 
            va='center', ha='left', color='red', fontsize=8)

# Adding grid lines
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Formatting date on x-axis
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# Set x-axis limit to September 30, 2024
ax.set_xlim([pd.Timestamp('2021-01-01'), pd.Timestamp('2024-09-30')])

# Adding labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Gliders')
ax.set_title('Glider Operational Days with Multiple Deployments')

plt.tight_layout()
plt.savefig('glider_ops.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# Dummy data for a single glider with two deployments
data = {
    'Glider': ['001', '001'],
    'Deployment_Date': ['2023-01-01', '2023-02-01'],
    'Retrieval_Date': ['2023-01-15', '2023-02-20']
}

# Convert to DataFrame
df = pd.DataFrame(data)
df['Deployment_Date'] = pd.to_datetime(df['Deployment_Date'])
df['Retrieval_Date'] = pd.to_datetime(df['Retrieval_Date'])

# Calculate operational days
df['Operational_Days'] = (df['Retrieval_Date'] - df['Deployment_Date']).dt.days

# Plot
plt.figure(figsize=(10, 6))
y_pos = range(len(df))

for i, row in df.iterrows():
    # Draw the bar
    plt.barh(row['Glider'], row['Operational_Days'],
             left=row['Deployment_Date'], color='skyblue', edgecolor='black')
    
    # Add deployment date line
    plt.axvline(row['Deployment_Date'], color='green', linestyle='--', linewidth=2)
    plt.text(row['Deployment_Date'], i, row['Deployment_Date'].strftime('%Y-%m-%d'), 
             verticalalignment='center', color='green', fontsize=10, fontweight='bold')
    
    # Add retrieval date line
    plt.axvline(row['Retrieval_Date'], color='red', linestyle='--', linewidth=2)
    plt.text(row['Retrieval_Date'], i, row['Retrieval_Date'].strftime('%Y-%m-%d'), 
             verticalalignment='center', color='red', fontsize=10, fontweight='bold')
    
    # Add the number of operational days on the bar
    plt.text(row['Deployment_Date'] + (row['Retrieval_Date'] - row['Deployment_Date']) / 2,
             i, f'{row["Operational_Days"]} days', color='black', 
             ha='center', va='center', fontweight='bold')

# Formatting the plot
plt.xlabel('Date')
plt.ylabel('Glider ID')
plt.title('Glider Operational Days with Deployment and Retrieval Dates')
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# Dummy data for 8 gliders
data = {
    'Glider': ['890', '890', '891', '891', '1095', '1096', '1127', '1127', '1128', '1130', '1131'],
    'Deployment_Date': ['2021-01-26', '2023-03-08', '2021-01-30', '2023-03-08', '2023-09-23', '2023-09-23', '2023-10-27', '2024-07-02', '2024-04-27', '2024-04-27', '2024-01-30'],
    'Retrieval_Date':   ['2021-05-18', '2023-07-07', '2021-05-20', '2023-04-20', '2024-04-23', '2024-03-23', '2024-06-28', '2024-07-10', '2024-12-31', '2024-12-31', '2024-12-31']
}

# Convert to DataFrame
df = pd.DataFrame(data)
df['Deployment_Date'] = pd.to_datetime(df['Deployment_Date'])
df['Retrieval_Date'] = pd.to_datetime(df['Retrieval_Date'])

# Calculate operational days
df['Operational_Days'] = (df['Retrieval_Date'] - df['Deployment_Date']).dt.days

# Plot
plt.figure(figsize=(12, 8))
y_pos = range(len(df))

for i, row in df.iterrows():
    # Draw the bar
    plt.barh(row['Glider'], row['Operational_Days'],
             left=row['Deployment_Date'], color='skyblue', edgecolor='black')
    
    # Add deployment date line
    plt.axvline(row['Deployment_Date'], color='green', linestyle='--', linewidth=2)
    plt.text(row['Deployment_Date'], i, row['Deployment_Date'].strftime('%Y-%m-%d'), 
             verticalalignment='center', color='green', fontsize=10, fontweight='bold')
    
    # Add retrieval date line
    plt.axvline(row['Retrieval_Date'], color='red', linestyle='--', linewidth=2)
    plt.text(row['Retrieval_Date'], i, row['Retrieval_Date'].strftime('%Y-%m-%d'), 
             verticalalignment='center', color='red', fontsize=10, fontweight='bold')
    
    # Add the number of operational days on the bar
    plt.text(row['Deployment_Date'] + (row['Retrieval_Date'] - row['Deployment_Date']) / 2,
             i, f'{row["Operational_Days"]} days', color='black', 
             ha='center', va='center', fontweight='bold')

# Formatting the plot
plt.xlabel('Date')
plt.ylabel('Glider ID')
plt.title('Glider Operational Days with Deployment and Retrieval Dates')
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# Provided data
data = {
    'Glider': ['890', '890', '891', '891', '1095', '1096', '1127', '1127', '1128', '1130', '1131'],
    'Deployment_Date': ['2021-01-26', '2023-03-08', '2021-01-30', '2023-03-08', '2023-09-23', '2023-09-23', '2023-10-27', '2024-07-02', '2024-04-27', '2024-04-27', '2024-01-30'],
    'Retrieval_Date':   ['2021-05-18', '2023-07-07', '2021-05-20', '2023-04-20', '2024-04-23', '2024-03-23', '2024-06-28', '2024-07-10', '2024-12-31', '2024-12-31', '2024-12-31']
}

# Convert to DataFrame
df = pd.DataFrame(data)
df['Deployment_Date'] = pd.to_datetime(df['Deployment_Date'])
df['Retrieval_Date'] = pd.to_datetime(df['Retrieval_Date'])

# Calculate operational days
df['Operational_Days'] = (df['Retrieval_Date'] - df['Deployment_Date']).dt.days

# Plot
plt.figure(figsize=(14, 8))
y_pos = range(len(df))

for i, row in df.iterrows():
    # Draw the bar
    plt.barh(row['Glider'], row['Operational_Days'],
             left=row['Deployment_Date'], color='skyblue', edgecolor='black')
    
    # Add deployment date line
    plt.axvline(row['Deployment_Date'], color='green', linestyle='--', linewidth=2, ymin=i/len(df)+0.02, ymax=(i+1)/len(df)-0.02)
    plt.text(row['Deployment_Date'], i-0.2, row['Deployment_Date'].strftime('%Y-%m-%d'), 
             verticalalignment='center', color='green', fontsize=10, fontweight='bold')
    
    # Add retrieval date line
    plt.axvline(row['Retrieval_Date'], color='red', linestyle='--', linewidth=2, ymin=i/len(df)+0.02, ymax=(i+1)/len(df)-0.02)
    plt.text(row['Retrieval_Date'], i+0.2, row['Retrieval_Date'].strftime('%Y-%m-%d'), 
             verticalalignment='center', color='red', fontsize=10, fontweight='bold')
    
    # Add the number of operational days on the bar
    plt.text(row['Deployment_Date'] + (row['Retrieval_Date'] - row['Deployment_Date']) / 2,
             i, f'{row["Operational_Days"]} days', color='black', 
             ha='center', va='center', fontweight='bold')

# Formatting the plot
plt.xlabel('Date')
plt.ylabel('Glider ID')
plt.title('Glider Operational Days with Deployment and Retrieval Dates')
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# Provided data
data = {
    'Glider': ['890', '890', '891', '891', '1095', '1096', '1127', '1127', '1128', '1130', '1131'],
    'Deployment_Date': ['2021-01-26', '2023-03-08', '2021-01-30', '2023-03-08', '2023-09-23', '2023-09-23', '2023-10-27', '2024-07-02', '2024-04-27', '2024-04-27', '2024-01-30'],
    'Retrieval_Date':   ['2021-05-18', '2023-07-07', '2021-05-20', '2023-04-20', '2024-04-23', '2024-03-23', '2024-06-28', '2024-07-10', '2024-12-31', '2024-12-31', '2024-12-31']
}

# Convert to DataFrame
df = pd.DataFrame(data)
df['Deployment_Date'] = pd.to_datetime(df['Deployment_Date'])
df['Retrieval_Date'] = pd.to_datetime(df['Retrieval_Date'])

# Calculate operational days
df['Operational_Days'] = (df['Retrieval_Date'] - df['Deployment_Date']).dt.days

# Plot
plt.figure(figsize=(14, 8))
y_pos = range(len(df))

for i, row in df.iterrows():
    # Draw the bar
    plt.barh(row['Glider'], row['Operational_Days'],
             left=row['Deployment_Date'], color='skyblue', edgecolor='black')
    
    # Add deployment date line
    plt.axvline(row['Deployment_Date'], color='green', linestyle='--', linewidth=2, ymin=(i+0.4)/len(df), ymax=(i+0.6)/len(df))
    plt.text(row['Deployment_Date'], i, row['Deployment_Date'].strftime('%Y-%m-%d'), 
             verticalalignment='center', color='green', fontsize=10, fontweight='bold', ha='right', va='bottom')
    
    # Add retrieval date line
    plt.axvline(row['Retrieval_Date'], color='red', linestyle='--', linewidth=2, ymin=(i+0.4)/len(df), ymax=(i+0.6)/len(df))
    plt.text(row['Retrieval_Date'], i, row['Retrieval_Date'].strftime('%Y-%m-%d'), 
             verticalalignment='center', color='red', fontsize=10, fontweight='bold', ha='left', va='top')
    
    # Add the number of operational days on the bar
    plt.text(row['Deployment_Date'] + (row['Retrieval_Date'] - row['Deployment_Date']) / 2,
             i, f'{row["Operational_Days"]} days', color='black', 
             ha='center', va='center', fontweight='bold')

# Formatting the plot
plt.xlabel('Date')
plt.ylabel('Glider ID')
plt.title('Glider Operational Days with Deployment and Retrieval Dates')
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()

# Display the plot
plt.show()

# %%
pwd
# Out:
# 'C:\\Users\\ravic'
