# %%
import pygmt

fig = pygmt.Figure()

# %%
with fig.subplot(nrows=2, ncols=3, figsize=("15c", "6c"), frame="lrtb"):
    for i in range(2):  # row number starting from 0
        for j in range(3):  # column number starting from 0
            index = i * 3 + j  # index number starting from 0
            with fig.set_panel(panel=index):  # sets the current panel
                fig.text(
                    position="MC",
                    text=f"index: {index}; row: {i}, col: {j}",
                    region=[0, 1, 0, 1],
                )
fig.show()

# %%
import pygmt
#pygmt.show_versions()

# %%
import pygmt

# %%
fig = pygmt.Figure()

fig.plot(
    region = [0, 10, 0, 10],
    projection = "X15c/10c",
    frame = "a",
    x = [1,6, 9],
    y = [5, 7, 4],
    pen = "1p, black"
)

fig.show()
# Out:
# plot [WARNING]: Representation of pen color (\040black) not recognized. Using default.

# %%
fig = pygmt.Figure()
fig.plot(
    region = [0, 10, 0, 10],
    projection = "X15c/10c",
    frame = "a", 
    x = [1, 6, 9],
    y = [5, 7, 4],
    pen ="2p,blue",
)

fig.plot(x=[2,4,10], y= [3,6,9], pen="2p,red")
fig.show()

# %%
rate = 25013000
total_sft = 2316

per_sft = rate/total_sft

# %%
print(per_sft)
# Out:
# 10800.086355785837
