# %%
import pygmt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import pygmt
#
# ModuleNotFoundError: No module named 'pygmt'

# %%
data = pygmt.datasets.load_sample_data(name = "japan_quakes")

region = [

    data.longitude.min() -1,
    data.longitude.max() +1,
    data.latitude.min() -1,
    data.latitude.max() +1,
]

print(region)
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data = pygmt.datasets.load_sample_data(name = "japan_quakes")
#       3 region = [
#       4
#       5     data.longitude.min() -1,
#    (...)      8     data.latitude.max() +1,
#       9 ]
#      11 print(region)
#
# NameError: name 'pygmt' is not defined

# %%
fig = pygmt.Figure()
fig.basemap(region = region, projection = "M15c", frame = True)
fig.coast(land="black", water = "skyblue")
fig.plot(x=data.longitude, y=data.latitude, style = "c0.3c", fill="white",pen="black")
fig.show()

# %%
fig = pygmt.Figure()
fig.basemap(region = region, projection = "M15c", frame = True)
fig.coast(land="black", water = "skyblue")
fig.plot(
    x=data.longitude, 
    y=data.latitude, 
    size = 0.02 * (2**data.magnitude),
    style = "cc", 
    fill="white",
    pen="black",
)
fig.show()

# %%
fig = pygmt.Figure()
fig.basemap(region = region, projection = "M15c", frame = True)
fig.coast(land="black", water = "skyblue")
pygmt.makecpt(cmap="viridis", series = [data.depth_km.min(), data.depth_km.max()])
fig.plot(
    x=data.longitude, 
    y=data.latitude, 
    size = 0.02 * (2**data.magnitude),
    style = "cc", 
    fill= data.depth_km,
    cmap = True,
    pen="black",
)
fig.colorbar(frame="xaf+lDepth (km)")
fig.show()
