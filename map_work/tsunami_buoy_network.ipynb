# %%
import pygmt
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# %%
# Working Code for Plot Generation
# Define the Indian Ocean Region region
region = [60, 100, 0, 30]

# Tsunami Buoy locations 
stb_buoys = {
    "name": ["STB-01", "STB-02"],
    "latitude": [6.25, 20.80],
    "longitude": [88.88, 64.34],
    }

itb_buoys = {
    "name": ["ITB-05", "ITB-06", "ITB-09", "ITB-12"], 
    "latitude": [10.17, 13.71, 16.94, 20.18],
    "longitude": [88.49, 89.56, 89.99, 67.65],
}

# Create the figure
fig = pygmt.Figure()

# Draw the base map
fig.coast(
    region=region,
    projection="M15c",  # Mercator projection
    land="lightgray",
    water="lightblue",
    shorelines="1/0.5p,black",
    frame=["af"],# "+tIndian Tsunami Buoy Network"
    borders="1/0.5p,black",
    resolution="h"
)

# Plot STB Tsunami Buoys Location

fig.plot(
    x= stb_buoys["longitude"],
    y= stb_buoys["latitude"], 
    style="t0.4c",  # Triangle symbol
    fill="red",
    pen="black",
    label="INCOIS Network"
    )

# Plot STB Tsunami Buoys Labels

fig.text(
    x= [i+1 for i in stb_buoys["longitude"]],
    y= [i+1 for i in stb_buoys["latitude"]],
    text=stb_buoys["name"],
    font="10p,Helvetica-Bold,black"
    )


# Plot ITB Tsunami Buoys Locations

fig.plot(
    x=itb_buoys["longitude"],
    y=itb_buoys["latitude"],
    style="c0.4c",  # Triangle symbol
    fill="green",
    pen="black",
    label="NIOT Network"
    )

# Plot ITB Tsunami Buoys Labels

fig.text(
    x=[i+1 for i in itb_buoys["longitude"]],
    y=[i+1 for i in itb_buoys["latitude"]],
    text=itb_buoys["name"],
    font="10p,Helvetica-Bold,black",
    )

fig.legend(position="JTL+jTL+o0.5c", box=True)

fig.savefig("indian_tsunami_buoy_network2.jpeg", dpi = 500)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[5], line 76
#      67 fig.text(
#      68     x=[i+1 for i in itb_buoys["longitude"]],
#      69     y=[i+1 for i in itb_buoys["latitude"]],
#      70     text=itb_buoys["name"],
#      71     font="10p,Helvetica-Bold,black",
#      72     )
#      74 fig.legend(position="JTL+jTL+o0.5c", box=True)
# ---> 76 fig.savefig("indian_tsunami_buoy_network2.jpeg", dpi = 500)
#      77 fig.show()
#
# File c:\Users\ravic\miniconda3\envs\pygmt\Lib\site-packages\pygmt\figure.py:259, in Figure.savefig(self, fname, transparent, crop, anti_alias, show, worldfile, **kwargs)
#     257 # Rename if file extension doesn't match the input file suffix.
#     258 if ext != suffix[1:]:
# --> 259     fname.with_suffix("." + ext).rename(fname)
#     261 if show:
#     262     launch_external_viewer(str(fname))
#
# File c:\Users\ravic\miniconda3\envs\pygmt\Lib\pathlib\_local.py:767, in Path.rename(self, target)
#     757 def rename(self, target):
#     758     """
#     759     Rename this path to the target path.
#     760
#    (...)    765     Returns the new Path instance pointing to the target path.
#     766     """
# --> 767     os.rename(self, target)
#     768     return self.with_segments(target)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'indian_tsunami_buoy_network2.jpg' -> 'indian_tsunami_buoy_network2.jpeg'

# %%
# Working Code for Plot Generation Without Legend
# Define the Indian Ocean Region region
region = [60, 100, 0, 30]

# Tsunami Buoy locations 
stb_buoys = {
    "name": ["STB-01", "STB-02"],
    "latitude": [6.25, 20.80],
    "longitude": [88.88, 64.34],
    }

itb_buoys = {
    "name": ["ITB-05", "ITB-06", "ITB-09", "ITB-12"], 
    "latitude": [10.17, 13.71, 16.94, 20.18],
    "longitude": [88.49, 89.56, 89.99, 67.65],
}

# Create the figure
fig = pygmt.Figure()

# Draw the base map
fig.coast(
    region=region,
    projection="M15c",  # Mercator projection
    land="lightgray",
    water="lightblue",
    shorelines="1/0.5p,black",
    frame=["af"], # "+tIndian Tsunami Buoy Network"
    borders="1/0.5p,black",
    resolution="h"
)

# Plot STB Tsunami Buoys Location

fig.plot(
    x= stb_buoys["longitude"],
    y= stb_buoys["latitude"], 
    style="t0.4c",  # Triangle symbol
    fill="red",
    pen="black"
    )

# Plot STB Tsunami Buoys Labels

fig.text(
    x= [i+1 for i in stb_buoys["longitude"]],
    y= [i+1 for i in stb_buoys["latitude"]],
    text=stb_buoys["name"],
    font="10p,Helvetica-Bold,black"
    )


# Plot ITB Tsunami Buoys Locations

fig.plot(
    x=itb_buoys["longitude"],
    y=itb_buoys["latitude"],
    style="c0.4c",  # Triangle symbol
    fill="green",
    pen="black"
    )

# Plot ITB Tsunami Buoys Labels

fig.text(
    x=[i+1 for i in itb_buoys["longitude"]],
    y=[i+1 for i in itb_buoys["latitude"]],
    text=itb_buoys["name"],
    font="10p,Helvetica-Bold,black"
    )

# fig.savefig("indian_tsunami_buoy_network1.jpeg", dpi = 500)
fig.show()

# %%
# Sample Code 
region = [60, 100, 0, 28]

# Tsunami Buoy locations 
stb_buoys = {
    "name": ["STB-01", "STB-02"],
    "latitude": [6.25, 20.80],
    "longitude": [88.88, 64.34],
    }

itb_buoys = {
    "name": ["ITB-05", "ITB-06", "ITB-09", "ITB-12"], 
    "latitude": [10.17, 13.71, 16.94, 20.18],
    "longitude": [88.49, 89.56, 89.99, 67.65],
}


# Create the figure
fig = pygmt.Figure()

# Draw the base map
fig.coast(
    region=region,
    projection="M15c",  # Mercator projection
    land="lightgray",
    water="lightblue",
    shorelines="1/0.5p,black",
    frame=["af", "+tIndian Tsunami Buoy Network"],
    borders="1/0.5p,black",
    resolution="h"
)

# Plot Tsunami Buoys

fig.plot(
    x= stb_buoys["longitude"],
    y= stb_buoys["latitude"], 
    style="t0.5c",  # Triangle symbol
    fill="red",
    pen="black"
    )

# Plot Tsunami Buoys

fig.text(
    x= [i+1 for i in stb_buoys["longitude"]],
    y= [i+1 for i in stb_buoys["latitude"]],
    text=stb_buoys["name"],
    font="10p,Helvetica-Bold,black"
    )

# Plot Tsunami Buoys
fig.plot(
    x=itb_buoys["longitude"],
    y=itb_buoys["latitude"],
    style="c0.5c",  # Triangle symbol
    fill="green",
    pen="black"
    )
fig.text(
    x=[i+1 for i in itb_buoys["longitude"]],
    y=[i+1 for i in itb_buoys["latitude"]],
    text=itb_buoys["name"],
    font="10p,Helvetica-Bold,black"
    )

fig.legend(position = "JBR+jBR+o0.5c", box='1p, black, gray')
# Show the plot
fig.savefig("indian_tsunami_buoy_network1.jpeg", dpi = 500)
fig.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Define the Indian Ocean Region extent
extent = [60, 100, 0, 30]

# Tsunami Buoy locations
stb_buoys = {
    "name": ["STB-01", "STB-02"],
    "latitude": [6.25, 20.80],
    "longitude": [88.88, 64.34],
}

itb_buoys = {
    "name": ["ITB-05", "ITB-06", "ITB-09", "ITB-12"],
    "latitude": [10.17, 13.71, 16.94, 20.18],
    "longitude": [88.49, 89.56, 89.99, 67.65],
}

# Create figure and Mercator projection
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.Mercator())
ax.set_extent(extent, crs=ccrs.PlateCarree())
# ax.set_title("Indian Tsunami Buoy Network", fontsize=14, weight='bold')

# Add map features
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='lightblue')
ax.add_feature(cfeature.COASTLINE, linewidth=0.5)
ax.add_feature(cfeature.BORDERS, linewidth=0.5)
ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', alpha=0.5, linestyle='--')

# Plot STB buoys
ax.plot(
    stb_buoys["longitude"], stb_buoys["latitude"],
    marker="^", color="red", markeredgecolor="black",
    linestyle="", transform=ccrs.PlateCarree(), label='STB Buoys'
)

# Plot STB labels
for lon, lat, name in zip(stb_buoys["longitude"], stb_buoys["latitude"], stb_buoys["name"]):
    ax.text(lon + 1, lat + 1, name, fontsize=10, fontweight='bold',
            transform=ccrs.PlateCarree(), color='black')

# Plot ITB buoys
ax.plot(
    itb_buoys["longitude"], itb_buoys["latitude"],
    marker="o", color="green", markeredgecolor="black",
    linestyle="", transform=ccrs.PlateCarree(), label='ITB Buoys'
)

# Plot ITB labels
for lon, lat, name in zip(itb_buoys["longitude"], itb_buoys["latitude"], itb_buoys["name"]):
    ax.text(lon + 1, lat + 1, name, fontsize=10, fontweight='bold',
            transform=ccrs.PlateCarree(), color='black')

# Show legend and plot
plt.legend(loc= "lower left")
plt.savefig("tsunami_buoy_network_1.png")
plt.show()
